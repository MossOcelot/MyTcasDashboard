# %%
import pandas
df = pandas.read_csv("../tcas_dataset_cleaned.csv")
df = df.drop(columns=["Unnamed: 0"])
print(df.columns)
# Out:
# Index(['university', 'major', 'course', 'ชื่อหลักสูตร',
#        'ชื่อหลักสูตรภาษาอังกฤษ', 'ประเภทหลักสูตร', 'วิทยาเขต', 'ค่าใช้จ่าย',
#        'อัตราการสำเร็จการศึกษา', 'รอบ 1 Portfolio', 'รอบ 2 Quota',
#        'รอบ 3 Admission', 'รอบ 4 Direct Admission'],
#       dtype='object')

# %%
df["ค่าใช้จ่าย"].unique()
# Out:
# array([ 25500.  ,      0.  ,   8650.  ,  10150.  ,  10800.  ,  23000.  ,
#         35000.  ,  50000.  ,  29000.  ,  25000.  ,  60000.  ,  30000.  ,
#         18000.  ,  18200.  ,  90000.  ,  52000.  ,  57000.  ,  32400.  ,
#          9025.  ,   9062.5 ,   8246.25,  16000.  ,  40000.  ,  75000.  ,
#         15000.  ,  33000.  ,  80000.  ,  19000.  ,  28000.  ,  59000.  ,
#        120000.  ,  37000.  ,  17000.  ,  46000.  ,  47500.  ,  37937.5 ,
#         41231.25,  41687.5 ,  37706.25,  40825.  ,  38212.5 ,  42500.  ])

# %%
df[df["university"] == "มหาวิทยาลัยศรีปทุม"]
# Out:
#              university              major  \
# 288  มหาวิทยาลัยศรีปทุม  วิศวกรรมเครื่องกล
# 289  มหาวิทยาลัยศรีปทุม  วิศวกรรมเครื่องกล
# 290  มหาวิทยาลัยศรีปทุม  วิศวกรรมเครื่องกล
# 291  มหาวิทยาลัยศรีปทุม      วิศวกรรมไฟฟ้า
# 292  มหาวิทยาลัยศรีปทุม      วิศวกรรมไฟฟ้า
# 293  มหาวิทยาลัยศรีปทุม       วิศวกรรมโยธา
# 294  มหาวิทยาลัยศรีปทุม       วิศวกรรมโยธา
# 295  มหาวิทยาลัยศรีปทุม    วิศวกรรมระบบราง
# 296  มหาวิทยาลัยศรีปทุม  วิศวกรรมอุตสาหการ
# 297  มหาวิทยาลัยศรีปทุม  วิศวกรรมอุตสาหการ
#
#                                                 course  \
# 288     วศ.บ. สาขาวิชาวิศวกรรมเครื่องกล (ภาษาไทย ปกติ)
# 289  วศ.บ. สาขาวิชาวิศวกรรมเครื่องกล(เทคโนโลยีอาคาร...
# 290  วศ.บ. สาขาวิชาวิศวกรรมเครื่องกล(เทคโนโลยียานยน...
# 291         วศ.บ. สาขาวิชาวิศวกรรมไฟฟ้า (ภาษาไทย ปกติ)
# 292  วศ.บ. สาขาวิชาวิศวกรรมไฟฟ้า  (ระบบควบคุมอัตโนม...
# 293          วศ.บ. สาขาวิชาวิศวกรรมโยธา (ภาษาไทย ปกติ)
# 294  วศ.บ. สาขาวิชาวิศวกรรมโยธา(การจัดการงานก่อสร้า...
# ...

# %%
df
# Out:
#                  university                major  \
# 0     จุฬาลงกรณ์มหาวิทยาลัย       วิศวกรรมทั่วไป
# 1     จุฬาลงกรณ์มหาวิทยาลัย  วิศวกรรมคอมพิวเตอร์
# 2     จุฬาลงกรณ์มหาวิทยาลัย  วิศวกรรมคอมพิวเตอร์
# 3     จุฬาลงกรณ์มหาวิทยาลัย         วิศวกรรมเคมี
# 4     จุฬาลงกรณ์มหาวิทยาลัย   วิศวกรรมนิวเคลียร์
# ..                      ...                  ...
# 303         มหาวิทยาลัยสยาม         วิศวกรรมโยธา
# 304         มหาวิทยาลัยสยาม    วิศวกรรมอุตสาหการ
# 305  มหาวิทยาลัยหอการค้าไทย  วิศวกรรมคอมพิวเตอร์
# 306  มหาวิทยาลัยหอการค้าไทย        วิศวกรรมไฟฟ้า
# 307  มหาวิทยาลัยหอการค้าไทย   วิศวกรรมโลจิสติกส์
#
#                                                 course  \
# 0    หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมศา...
# 1    หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 2    หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 3    หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมเค...
# 4    หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมนิ...
# ...

# %%
df1 = df[df["university"] == "มหาวิทยาลัยหอการค้าไทย"]
df2 = df1[df1["major"] == "วิศวกรรมคอมพิวเตอร์"]
# df3 = df2[df2["course"] == course]
df2
# Out:
#                  university                major  \
# 305  มหาวิทยาลัยหอการค้าไทย  วิศวกรรมคอมพิวเตอร์
#
#                                                 course  \
# 305  หลักสูตรวิศวกรรมศาสตรบัณฑิต (วิศวกรรมคอมพิวเตอ...
#
#                                           ชื่อหลักสูตร  \
# 305  หลักสูตรวิศวกรรมศาสตรบัณฑิต (วิศวกรรมคอมพิวเตอ...
#
#                                 ชื่อหลักสูตรภาษาอังกฤษ ประเภทหลักสูตร  \
# 305  B.Eng. (Computer Engineering and Artificial In...   ภาษาไทย ปกติ
#
#          วิทยาเขต  ค่าใช้จ่าย อัตราการสำเร็จการศึกษา  รอบ 1 Portfolio  \
# 305  วิทยาเขตหลัก     42500.0                  80.0%                0
#
#      รอบ 2 Quota  รอบ 3 Admission  รอบ 4 Direct Admission
# 305            0               60                       0

# %%
df2["รอบ 1 Portfolio"].to_list()[0]
# Out:
# 0
