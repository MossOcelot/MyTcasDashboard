# %%
import pandas as pd

# %%
df = pd.read_csv("tcas_dataset.csv")
df.head()
# Out:
#    Unnamed: 0             university                   major  \
# 0           0  จุฬาลงกรณ์มหาวิทยาลัย       1. วิศวกรรมทั่วไป
# 1           1  จุฬาลงกรณ์มหาวิทยาลัย  2. วิศวกรรมคอมพิวเตอร์
# 2           2  จุฬาลงกรณ์มหาวิทยาลัย  2. วิศวกรรมคอมพิวเตอร์
# 3           3  จุฬาลงกรณ์มหาวิทยาลัย         3. วิศวกรรมเคมี
# 4           4  จุฬาลงกรณ์มหาวิทยาลัย   4. วิศวกรรมนิวเคลียร์
#
#                                               course  \
# 0  1. หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรร...
# 1  1. หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรร...
# 2  2. หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรร...
# 3  1. หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรร...
# 4  1. หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรร...
#
#                                         ชื่อหลักสูตร  \
# 0  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมศา...
# 1  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 2  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...
# 3  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมเค...
# ...

# %%
def payFunction(text):
    if "ภาคการศึกษา" in text:
        pass
    elif "ตลอดหลักสูตร" in text:
        pass

df['ค่าใช้จ่าย'] = df['ค่าใช้จ่าย'].apply(payFunction)
# Out:
# 0      ภาคการศึกษาต้นและภาคการศึกษาปลาย ภาคการศึกษาละ...
# 1      ภาคการศึกษาต้นและภาคการศึกษาปลาย ภาคการศึกษาละ...
# 2      ภาคการศึกษาต้นและภาคการศึกษาปลาย ภาคการศึกษาละ...
# 3      ดูรายละเอียดเพิ่มเติม https://www.chula.ac.th/...
# 4      ภาคการศึกษาต้นและภาคการศึกษาปลาย ภาคการศึกษาละ...
#                              ...
# 303    ประมาณการอัตราค่าเล่าเรียน ตลอดหลักสูตร 326,60...
# 304    ประมาณการอัตราค่าเล่าเรียน ตลอดหลักสูตร 305,70...
# 305           อัตราค่าเล่าเรียน 340,000 บาท ตลอดหลักสูตร
# 306           อัตราค่าเล่าเรียน 340,000 บาท ตลอดหลักสูตร
# 307           อัตราค่าเล่าเรียน 340,000 บาท ตลอดหลักสูตร
# Name: ค่าใช้จ่าย, Length: 308, dtype: object
